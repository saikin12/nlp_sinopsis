# %%
import pandas as pd
import numpy as np
import string
import re
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from nltk.corpus import stopwords

# %%
df=pd.read_csv("encoded_genres.tsv", sep='\t', index_col=0)

# %%
df.head()
# Out:
#        tconst                                  title  release_year  \
# 0   tt0010323           Das Cabinet des Dr. Caligari          1920
# 10  tt0011387               The Last of the Mohicans          1920
# 11  tt0011000                    Blade af Satans bog          1920
# 18  tt0012763                    Tol&apos;able David          1921
# 26  tt0013442  Nosferatu, eine Symphonie des Grauens          1922
#
#    release_date                                         plot_short  \
# 0    1920-02-27  Hypnotist Dr. Caligari uses a somnambulist, Ce...
# 10   1920-11-21  In the midst of the French and Indian War, the...
# 11   1921-01-24  In 4 episodic tales of human suffering: the te...
# 18   1921-12-31  When three thuggish men are responsible for th...
# 26   1922-05-18  Vampire Count Orlok expresses interest in a ne...
#
#                                             plot_long  \
# 0   Francis, a young man, recalls in his memory th...
# ...

# %%
df.shape
# Out:
# (10961, 29)
